# %%
import os
from dotenv import load_dotenv
load_dotenv()
NOTION_API_KEY = os.getenv("NOTION_API_KEY")
NOTION_ROOT_ID = os.getenv("NOTION_ROOT_ID")

# %%
from notion_client import Client, AsyncClient

# Initialize a client with the integration token
notion = Client(auth=NOTION_API_KEY)

# %%
NOTION_API_KEY
# Out:
# 'secret_3u8uvwjI5KwCpgRxnTdAXNeNlQLgkjZsjPkOE101RlM'

# %%
page_id = NOTION_ROOT_ID

# Retrieve the page
page = notion.pages.retrieve(page_id=page_id)

# Print page properties
print(page["properties"])
# Out:
# {'title': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Франция | Гайд по иммиграции и интеграции', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Франция | Гайд по иммиграции и интеграции', 'href': None}]}}

# %%
def retrieve_blocks(page_id):
    all_blocks = []
    start_cursor = None
    while True:
        response = notion.blocks.children.list(block_id=page_id, start_cursor=start_cursor)
        blocks = response.get("results", [])
        all_blocks.extend(blocks)
        if not response.get("has_more", False):
            break
        start_cursor = response.get("next_cursor", None)
    return all_blocks

root_page_id = "a283ff3a46804b39b50e29c566369c2f"

# Retrieve blocks from the root page
blocks = retrieve_blocks(root_page_id)
visited_ids = set()

def retrieve_all_blocks(blocks, level=0):
    all_blocks = []
    for block in blocks:
        if block["id"] not in visited_ids:
            #print("  " * level + block["type"], block.get("id", ""))
            all_blocks.append(block)
            visited_ids.add(block["id"])
            if block.get("has_children", False):
                child_blocks = retrieve_blocks(block["id"])
                new_blocks = retrieve_all_blocks(child_blocks, level + 1)
                all_blocks.extend(new_blocks) if new_blocks else None
    return all_blocks

# Start retrieving all nested blocks
all_blocks = retrieve_all_blocks(blocks)

# %%
for i, block in enumerate(all_blocks):
    if "https://www.defenseurdesdroits.fr/carte-des-delegues" in str(block):
        print(block)
        print(i)
# Out:
# {'object': 'block', 'id': '2b57680d-bea5-467f-be59-2a628cc568a4', 'parent': {'type': 'page_id', 'page_id': 'a283ff3a-4680-4b39-b50e-29c566369c2f'}, 'created_time': '2023-11-22T22:35:00.000Z', 'last_edited_time': '2024-02-11T16:43:00.000Z', 'created_by': {'object': 'user', 'id': 'b3f81ee4-df58-4e55-9feb-8945047c0018'}, 'last_edited_by': {'object': 'user', 'id': '5fd4d45c-7a31-400a-931f-98b0d14cdf45'}, 'has_children': False, 'archived': False, 'in_trash': False, 'type': 'bookmark', 'bookmark': {'caption': [], 'url': 'https://www.defenseurdesdroits.fr/carte-des-delegues'}}
# 132

# %%
print(all_blocks[131])
# Out:
# {'object': 'block', 'id': '5e5a2fea-b438-4fbb-bfd5-1cb3b0d7ae64', 'parent': {'type': 'page_id', 'page_id': 'a283ff3a-4680-4b39-b50e-29c566369c2f'}, 'created_time': '2023-11-22T22:35:00.000Z', 'last_edited_time': '2024-02-11T16:43:00.000Z', 'created_by': {'object': 'user', 'id': 'b3f81ee4-df58-4e55-9feb-8945047c0018'}, 'last_edited_by': {'object': 'user', 'id': '5fd4d45c-7a31-400a-931f-98b0d14cdf45'}, 'has_children': False, 'archived': False, 'in_trash': False, 'type': 'quote', 'quote': {'rich_text': [{'type': 'text', 'text': {'content': 'Найти ближайшего представителя Défenseur des droits (имеет значение территориальная юрисдикция) можно по этой ссылке:', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Найти ближайшего представителя Défenseur des droits (имеет значение территориальная юрисдикция) можно по этой ссылке:', 'href': None}], 'color': 'default'}}

# %%
import os
from dotenv import load_dotenv
load_dotenv()
NOTION_API_KEY = os.getenv("NOTION_API_KEY")
NOTION_ROOT_ID = os.getenv("NOTION_ROOT_ID")

# %%
from danswer.connectors.notion.connector import NotionConnector

# %%
connector = NotionConnector(root_page_id="a283ff3a46804b39b50e29c566369c2f") # just one page here
connector.load_credentials({"notion_integration_token": NOTION_API_KEY})

# %%
out = [_ for _ in connector.load_from_state()]
# Out:
# 06/07/2024 12:29:36 AM         connector.py 386 : Recursively loading pages from Notion based on root page with ID: a283ff3a46804b39b50e29c566369c2f
# 06/07/2024 12:29:37 AM         connector.py 300 : Reading page with ID 'a283ff3a-4680-4b39-b50e-29c566369c2f', with url https://www.notion.so/a283ff3a46804b39b50e29c566369c2f

# %%
print(out)
# Out:
# [[Document(id='a283ff3a-4680-4b39-b50e-29c566369c2f', sections=[Section(text='', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f'), Section(text='Данная статья может показаться вам сложной, однако после ее прочтения вы будете точно знать, в какие структуры вы можете обратиться по вашему вопросу.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#68340d07715a43fa8ed48f7d7faeca66'), Section(text='Из этой статьи вы узнаете, чем отличаются между собой понятия \nдоступ к юридической помощи\n (accès au droit) и \nдоступ к социальной поддержке\n (accès aux droits), которые одинаково звучат на французском языке. Кроме того, мы расскажем в статье, какие структуры ответственны за эти два сектора поддержки.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#d968fe0b4d4247be8200e2b50d9443de'), Section(text='Определение и социальные задачи', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#f1bf516747474852aa88eaa70e15afc6'), Section(text='Согласно гражданскому кодексу Франции "Все должны знать закон" (Nul n’est censé ignorer la loi).\xa0Однако неспециалисту трудно разбираться в содержании 74 французских кодексов. ', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#28564a05e0964cdf81a5eea84b3b3cb3'), Section(text='В связи с этим, предоставление информации, необходимой для реализации прав и выполнения обязанностей, а также доступность и эффективность права и правосудия является одной из приоритетных миссий государства (service publique). Как и многие другие важные миссии, государство, следуя логике либеральной  децентализации, частично делегирует \nдоступ к юридической помощи \n(un service public de l’accès\xa0\nau\xa0droit\n)\n другим структурам, которые будут рассмотрены ниже в разделе “Устройство системы доступа к юридической помощи”.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#1f0a314c674643af96485311c5891b77'), Section(text='https://www.legifrance.gouv.fr/', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#c5e990a84b8647b68ca55d8701ae733b'), Section(text='Не следует путать это понятие с\xa0\nдоступом к социальной поддержке (accès\xa0\naux\xa0droits\n), относящуюся к социальной сфере.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#e0c1c71f6a8b4f39858bf4997cf82b30'), Section(text='Понятие доступа к юридической помощи, определяемое законом от 10 июля 1991 года "О правовой помощи", включает в себя две составляющие:', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#c209d2994da7419ea4e775ad91652dc4'), Section(text='1. \nЮридическая помощь\n\xa0в доступе к правосудию, также называемая “вторичная правовая помощь” (Aide juridictionnelle)', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#0face5810c0c4be9b0e862d890b09e02'), Section(text='Юридическая помощь в доступе к правосудию (Aide juridictionnelle - AJ) заключается в предоставлении государством финансовой помощи на покрытие расходов на ведение дела (оплата услуг адвоката) в ходе судебного разбирательства.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#e922b8c0635c48908e55e49524420aca'), Section(text='Для\xa0\nполучения\xa0\nюридической помощи в доступе к правосудию (AJ) необходимо соответствовать трем следующим критериям:', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#f615e5c1505a4e429e671b7089488cf4'), Section(text='Ваш судебный иск не является явно неприемлемым (manifestement irrecevable) или необоснованным (dénuée de fondement);', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#6b3c76aea99f4164aa3ea71b1a83bba3'), Section(text='Ваши\xa0\nсудебные издержки\n\xa0не должны быть\xa0\nполностью покрыты страховкой;', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#b9dadd4a292a4a2d9fd2edab3c26119e'), Section(text='Базовый налоговый доход (Revenu fiscal de référence) \nрассчитывается налоговым органом и указывается отдельной строкой в налоговом уведомлении (avis d’impôt).', link='https://www.notion.so/a283ff3a4 ...

# %%
pages = [connector._fetch_page("a283ff3a46804b39b50e29c566369c2f")]

# %%
parsed_pages = []
for parsed_page in connector._read_pages(pages):
    parsed_pages.append(parsed_page)
# Out:
# 06/07/2024 12:09:21 AM         connector.py 300 : Reading page with ID 'a283ff3a-4680-4b39-b50e-29c566369c2f', with url https://www.notion.so/a283ff3a46804b39b50e29c566369c2f

# %%
for section in parsed_pages[0]:
    print(section)
# Out:
# ('id', 'a283ff3a-4680-4b39-b50e-29c566369c2f')
# ('sections', [Section(text='', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f'), Section(text='Данная статья может показаться вам сложной, однако после ее прочтения вы будете точно знать, в какие структуры вы можете обратиться по вашему вопросу.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#68340d07715a43fa8ed48f7d7faeca66'), Section(text='Из этой статьи вы узнаете, чем отличаются между собой понятия \nдоступ к юридической помощи\n (accès au droit) и \nдоступ к социальной поддержке\n (accès aux droits), которые одинаково звучат на французском языке. Кроме того, мы расскажем в статье, какие структуры ответственны за эти два сектора поддержки.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#d968fe0b4d4247be8200e2b50d9443de'), Section(text='Определение и социальные задачи', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#f1bf516747474852aa88eaa70e15afc6'), Section(text='Согласно гражданскому кодексу Франции "Все должны знать закон" (Nul n’est censé ignorer la loi).\xa0Однако неспециалисту трудно разбираться в содержании 74 французских кодексов. ', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#28564a05e0964cdf81a5eea84b3b3cb3'), Section(text='В связи с этим, предоставление информации, необходимой для реализации прав и выполнения обязанностей, а также доступность и эффективность права и правосудия является одной из приоритетных миссий государства (service publique). Как и многие другие важные миссии, государство, следуя логике либеральной  децентализации, частично делегирует \nдоступ к юридической помощи \n(un service public de l’accès\xa0\nau\xa0droit\n)\n другим структурам, которые будут рассмотрены ниже в разделе “Устройство системы доступа к юридической помощи”.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#1f0a314c674643af96485311c5891b77'), Section(text='Не следует путать это понятие с\xa0\nдоступом к социальной поддержке (accès\xa0\naux\xa0droits\n), относящуюся к социальной сфере.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#e0c1c71f6a8b4f39858bf4997cf82b30'), Section(text='Понятие доступа к юридической помощи, определяемое законом от 10 июля 1991 года "О правовой помощи", включает в себя две составляющие:', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#c209d2994da7419ea4e775ad91652dc4'), Section(text='1. \nЮридическая помощь\n\xa0в доступе к правосудию, также называемая “вторичная правовая помощь” (Aide juridictionnelle)', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#0face5810c0c4be9b0e862d890b09e02'), Section(text='Юридическая помощь в доступе к правосудию (Aide juridictionnelle - AJ) заключается в предоставлении государством финансовой помощи на покрытие расходов на ведение дела (оплата услуг адвоката) в ходе судебного разбирательства.', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#e922b8c0635c48908e55e49524420aca'), Section(text='Для\xa0\nполучения\xa0\nюридической помощи в доступе к правосудию (AJ) необходимо соответствовать трем следующим критериям:', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#f615e5c1505a4e429e671b7089488cf4'), Section(text='Ваш судебный иск не является явно неприемлемым (manifestement irrecevable) или необоснованным (dénuée de fondement);', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#6b3c76aea99f4164aa3ea71b1a83bba3'), Section(text='Ваши\xa0\nсудебные издержки\n\xa0не должны быть\xa0\nполностью покрыты страховкой;', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#b9dadd4a292a4a2d9fd2edab3c26119e'), Section(text='Базовый налоговый доход (Revenu fiscal de référence) \nрассчитывается налоговым органом и указывается отдельной строкой в налоговом уведомлении (avis d’impôt).', link='https://www.notion.so/a283ff3a46804b39b50e29c566369c2f#2c5a36d689304469a362080162793e64'), Section(text='Ваш \nбазовый налоговый доход,\n \nиспользуемый для расчетов \n(revenu fiscal de référence),\xa0\nи\xa0\nстоимость вашего ...
# ('source', <DocumentSource.NOTION: 'notion'>)
# ('semantic_identifier', 'Как получить бесплатную юридическую помощь')
# ('metadata', {})
# ('doc_updated_at', datetime.datetime(2024, 6, 6, 18, 55, tzinfo=datetime.timezone.utc))
# ('primary_owners', None)
# ('secondary_owners', None)
# ('title', None)
# ('from_ingestion_api', False)
